# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot

# %%
df_news = pd.read_csv("data/Bai_news_headlines.csv")
#df_news.set_index("date", inplace=True)
df_news.date = pd.to_datetime(df_news.date)

# %%
df_news.head()
# Out:
#         date                                          headlines
# 0 2011-03-29  PRECIOUS-Gold regains footing on equities, Lib...
# 1 2011-03-29  PRECIOUS-Gold regains footing, talk of cenbank...
# 2 2011-03-30  PRECIOUS-Gold edges up, heads for 10th quarter...
# 3 2011-03-30  PRECIOUS-Gold edges down after equity-driven r...
# 4 2011-03-30  NYMEX-Oil steadies above $104 on US crude stoc...

# %%
from textblob import TextBlob

# %%
polarity_list=[]
subject_list=[]
for each in df_news['headlines']:
    testimonial = TextBlob(each)
    polarity_list.append(testimonial.sentiment.polarity)
    subject_list.append(testimonial.sentiment.subjectivity)

df_news['polarity']=polarity_list
len(polarity_list)
# Out:
# 28220

# %%
grouped=df_news.groupby(['date']).mean() # take daily mean

# %%
grouped[:10]
# Out:
#             polarity
# date
# 2011-03-29  0.000000
# 2011-03-30 -0.063194
# 2011-03-31 -0.019444
# 2011-04-01  0.036667
# 2011-04-03  0.070000
# 2011-04-04  0.165185
# 2011-04-05 -0.141342
# 2011-04-06  0.026667
# 2011-04-07  0.030476
# 2011-04-08  0.094286

# %%
# TBC: is polarity list still needed?
# for i in range(len(df_news)):
#     date = str(df_news['date'][i])[:10]
#     polarity_list[i] = grouped.loc[date,'polarity']

# %%
# len(polarity_list)
# Out:
# 28220

# %%
import math

# %%
grouped.iloc[0].polarity
# Out:
# 0.0

# %%
cum_senti = []
for current_day_num in range(len(grouped)): # iterate through all days' sentment scores [0,n-1]
    daily_new_senti = grouped.iloc[current_day_num].polarity
    # for current day (t-th day), back track from [0,t-1]
    for back_track_day_num in range(current_day_num):
        # take exponential decay for polarity on i-th day where i:[0,t-1]
        daily_new_senti += grouped.iloc[back_track_day_num].polarity * math.exp(-(current_day_num-back_track_day_num)/7)
    cum_senti.append(daily_new_senti)

# %% [markdown]
# * for outer loop, iterate from 1st row (index 0) to last row (index n-1).
# * initialize temp var with averaged sentiment score on t-th day, then sum up all back tracked sentiment scores from 1st day (index 0) to 1 day before current day (t-1 th day) where each of them take exponential decay (power must be larger than 0 as current day should not be included in back tracking)
# * same shape for cum_senti list and averaged sentiment score list (grouped)

# %%
grouped['cum_senti']=cum_senti

# %%
new_polarity_list=[]
for i in range(len(df_news)):
    date = str(df_news['date'][i])[:10]
    new_polarity_list.append(grouped.loc[date,'cum_senti'])

# %%
df_news['cum_polarity']=new_polarity_list

# %%
df_news[:30]
# Out:
#          date                                          headlines  polarity  \
# 0  2011-03-29  PRECIOUS-Gold regains footing on equities, Lib...  0.000000
# 1  2011-03-29  PRECIOUS-Gold regains footing, talk of cenbank...  0.000000
# 2  2011-03-30  PRECIOUS-Gold edges up, heads for 10th quarter...  0.000000
# 3  2011-03-30  PRECIOUS-Gold edges down after equity-driven r... -0.155556
# 4  2011-03-30  NYMEX-Oil steadies above $104 on US crude stoc... -0.350000
# 5  2011-03-30  SOFTS-Cocoa drops as Ivorian rebel gains stoke...  0.000000
# 6  2011-03-30  GRAINS-Soybeans rise, corn slips in acreage ba...  0.000000
# 7  2011-03-30       SOFTS-Cocoa climbs back from 2-1/2 month low  0.000000
# 8  2011-03-30  METALS-Copper eases, doubts about China demand...  0.000000
# 9  2011-03-30  PRECIOUS-Gold rises along with equities, risk ...  0.000000
# 10 2011-03-31  PRECIOUS-Gold eases before U.S. payrolls data,...  0.000000
# 11 2011-03-31  CORRECTED-PRECIOUS-Gold eases before U.S. payr...  0.000000
# 12 2011-03-31  GRAINS-Surge on shrinking US stocks, corn limi...  0.000000
# 13 2011-03-31  METALS-Copper ends 1st quarter down on slack C... -0.155556
# 14 2011-03-31  GRAINS-Surge on shrinking US stocks, corn lock...  0.000000
# 15 2011-03-31   GRAINS-Corn, soybeans surge on bullish USDA data  0.000000
# 16 2011-03-31  METALS-Copper up on softer dollar, but China a...  0.000000
# 17 2011-03-31  PRECIOUS-Gold rises 1 pct, notches 10th quarte...  0.000000
# 18 2011-04-01  SOFTS-Cocoa in mild recovery as Ivorian battle...  0.333333
# 19 2011-04-01   GRAINS-Corn soars to post-2008 food crisis highs  0.000000
# 20 2011-04-01  SOFTS-Cocoa eases as Ouattara makes gains in I...  0.000000
# 21 2011-04-01  METALS-Copper hits 2-week low as demand still ... -0.150000
# 22 2011-04-01    PRECIOUS-Gold slips on U.S. jobs data, Fed eyed  0.000000
# 23 2011-04-03  PRECIOUS-Gold edges up on high oil prices, eur...  0.160000
# 24 2011-04-03  PRECIOUS-Gold inches up on firm euro, high oil... -0.020000
# 25 2011-04-04  PRECIOUS-Silver hits 31-year top, iShares Silv...  0.500000
# 26 2011-04-04  NYMEX-Crude dips from 2-1/2 year top; supply c...  0.500000
# 27 2011-04-04  PRECIOUS-Silver hits 31-year high, iShares Sil...  0.160000
# 28 2011-04-04  METALS-Copper ends lower as worry over China d...  0.000000
# 29 2011-04-04  GRAINS-Corn soars again, matches all-time high...  0.160000
#
#     cum_polarity
# 0       0.000000
# 1       0.000000
# 2      -0.063194
# 3      -0.063194
# 4      -0.063194
# 5      -0.063194
# 6      -0.063194
# 7      -0.063194
# 8      -0.063194
# 9      -0.063194
# 10     -0.082639
# 11     -0.082639
# 12     -0.082639
# 13     -0.082639
# 14     -0.082639
# 15     -0.082639
# 16     -0.082639
# 17     -0.082639
# 18     -0.081310
# 19     -0.081310
# 20     -0.081310
# 21     -0.081310
# 22     -0.081310
# 23     -0.095466
# 24     -0.095466
# 25     -0.041448
# 26     -0.041448
# 27     -0.041448
# 28     -0.041448
# 29     -0.041448

# %%
df_news.to_csv("news_title_with_2_sentiment_indicators.csv",index=False)
